# %% [markdown]
# # Práctico de detección de objetos
# El objetivo de este práctico es entrenar un detector de objetos en imágenes usando la red Yolo.

# %% [markdown]
# ## Entrenamiento en colab
#  * Montamos el drive en colab

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
#  * Chequeamos que esté instalado el compilador de *cuda*

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %% [markdown]
#  * Descomprimimos el dataset

# %%
# !unzip "/content/drive/My Drive/Colab Notebooks/darknet.zip"

# %% [markdown]
#  * Compilamos darknet, lo hacemos ejecutable.

# %%
# %cd /content/darknet
# !make clean
# !make
# !chmod +x ./darknet

# %% [markdown]
#  * Creamos un enlace simbólico entre colab y nuestro drive para guardar los modelos intermedios. Esto supone que existe una carpeta **colab/backup** en nuestro drive.

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/colab/backup /content/darknet

# %% [markdown]
#  * Si usamos windows para generar los archivos de configuración, instalamos una utilidad para linuxearlos y se la aplicamos a los archivos. Si usan linux para generar los archivos, háganlo igual porque hace alguna magia.

# %%
# !sudo apt install dos2unix

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/test.txt
# !dos2unix ./data/obj.data
# !dos2unix ./data/obj.names
# !dos2unix ./cfg/yolo-obj.cfg

# %%
# !./darknet detector test data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_final.weights data/obra.jpg -i 0 -thresh 0.25 -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
#    9 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
#   10 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   11 route  10 		                       1/2 ->   52 x  52 x  64
#   12 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   13 conv     64       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x  64 0.199 BF
#   14 route  13 12 	                           ->   52 x  52 x 128
#   15 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   16 route  10 15 	                           ->   52 x  52 x 256
#   17 max                2x 2/ 2     52 x  52 x 256 ->   26 x  26 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   19 route  18 		                       1/2 ->   26 x  26 x 128
#   20 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   21 conv    128       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 128 0.199 BF
#   22 route  21 20 	                           ->   26 x  26 x 256
#   23 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   24 route  18 23 	                           ->   26 x  26 x 512
#   25 max                2x 2/ 2     26 x  26 x 512 ->   13 x  13 x 512 0.000 BF
#   26 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   27 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   28 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   29 conv     24       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  24 0.004 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#   31 route  27 		                           ->   13 x  13 x 256
#   32 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   33 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   34 route  33 23 	                           ->   26 x  26 x 384
#   35 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   36 conv     24       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  24 0.008 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 6.790
# avg_outputs = 299930
#  Allocate additional workspace_size = 12.46 MB
# Loading weights from backup/yolo-obj_final.weights...
#  seen 64, trained: 384 K-images (6 Kilo-batches_64)
# Done! Loaded 38 layers from weights-file
#  Detection layer: 30 - type = 27
#  Detection layer: 37 - type = 27
# data/obra.jpg: Predicted in 15.639000 milli-seconds.
# helmet: 100%

# %% [markdown]
#  * Entrenamos nuestro propio modelo. Esto puede tardar aproximadamente un día.

# %%
# %cd /content/darknet
# !./darknet detector train data/obj.data cfg/yolo-obj.cfg yolov4-tiny.conv.29 -map -dont_show
#!./darknet detector train data/obj.data cfg/yolo-obj.cfg "/content/drive/My Drive/colab/backup/yolo-obj_last.weights" -map -dont_show
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.804845, GIOU: 0.799758), Class: 0.986286, Obj: 0.651164, No Obj: 0.001626, .5R: 1.000000, .75R: 0.694444, count: 36, class_loss = 0.200798, iou_loss = 0.379674, total_loss = 0.580472
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.751932, GIOU: 0.739345), Class: 0.959809, Obj: 0.690159, No Obj: 0.002442, .5R: 0.932271, .75R: 0.597610, count: 251, class_loss = 1.317425, iou_loss = 32.882690, total_loss = 34.200115
#  total_bbox = 1526844, rewritten_bbox = 0.988117 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5386: 0.759354, 0.713163 avg loss, 0.000261 rate, 1.138546 seconds, 344704 images, 0.280726 hours left
# Loaded: 0.000042 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.801472, GIOU: 0.792315), Class: 0.994743, Obj: 0.683186, No Obj: 0.001857, .5R: 0.977273, .75R: 0.727273, count: 44, class_loss = 0.236071, iou_loss = 0.528259, total_loss = 0.764330
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.755442, GIOU: 0.741840), Class: 0.968160, Obj: 0.719183, No Obj: 0.002816, .5R: 0.936396, .75R: 0.639576, count: 283, class_loss = 1.216175, iou_loss = 37.459774, total_loss = 38.675949
#  total_bbox = 1527171, rewritten_bbox = 0.988167 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5387: 0.726365, 0.714483 avg loss, 0.000261 rate, 1.151751 seconds, 344768 images, 0.279861 hours left
# Loaded: 0.000069 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.784701, GIOU: 0.773496), Class: 0.958009, Obj: 0.750916, No Obj: 0.001711, .5R: 0.941176, .75R: 0.735294, count: 34, class_loss = 0.134065, iou_loss = 0.300152, total_loss = 0.434217
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.724663, GIOU: 0.710465), Class: 0.960529, Obj: 0.693076, No Obj: 0.002622, .5R: 0.861940, .75R: 0.567164, count: 268, class_loss = 1.426265, iou_loss = 32.377831, total_loss = 33.804096
#  total_bbox = 1527473, rewritten_bbox = 0.988299 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5388: 0.780433, 0.721078 avg loss, 0.000261 rate, 1.151789 seconds, 344832 images, 0.279023 hours left
# Loaded: 0.000041 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.835973, GIOU: 0.833257), Class: 0.997509, Obj: 0.898887, No Obj: 0.001524, .5R: 1.000000, .75R: 0.900000, count: 30, class_loss = 0.040165, iou_loss = 0.343424, total_loss = 0.383589
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.747189, GIOU: 0.732942), Class: 0.959459, Obj: 0.691253, No Obj: 0.002236, .5R: 0.935780, .75R: 0.610092, count: 218, class_loss = 1.283310, iou_loss = 33.829269, total_loss = 35.112579
#  total_bbox = 1527721, rewritten_bbox = 0.988269 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5389: 0.661965, 0.715167 avg loss, 0.000261 rate, 1.149280 seconds, 344896 images, 0.278191 hours left
# Loaded: 0.000042 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.834480, GIOU: 0.830794), Class: 0.991865, Obj: 0.770873, No Obj: 0.001919, .5R: 1.000000, .75R: 0.782609, count: 46, class_loss = 0.135965, iou_loss = 0.496103, total_loss = 0.632068
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.749197, GIOU: 0.735300), Class: 0.956394, Obj: 0.643661, No Obj: 0.002889, .5R: 0.910345, .75R: 0.620690, count: 290, class_loss = 1.829911, iou_loss = 41.071144, total_loss = 42.901054
#  total_bbox = 1528057, rewritten_bbox = 0.988118 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5390: 0.983166, 0.741967 avg loss, 0.000261 rate, 1.157179 seconds, 344960 images, 0.277360 hours left
# Loaded: 0.000053 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.796068, GIOU: 0.790575), Class: 0.994506, Obj: 0.690961, No Obj: 0.001784, .5R: 0.950000, .75R: 0.800000, count: 40, class_loss = 0.164115, iou_loss = 0.380323, total_loss = 0.544438
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.717468, GIOU: 0.700648), Class: 0.955573, Obj: 0.670590, No Obj: 0.002326, .5R: 0.862500, .75R: 0.558333, count: 240, class_loss = 1.374572, iou_loss = 33.904404, total_loss = 35.278976
#  total_bbox = 1528337, rewritten_bbox = 0.988329 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5391: 0.769610, 0.744731 avg loss, 0.000261 rate, 1.160292 seconds, 345024 images, 0.276547 hours left
# Loaded: 0.000040 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.842048, GIOU: 0.838450), Class: 0.995288, Obj: 0.819480, No Obj: 0.001938, .5R: 0.974359, .75R: 0.948718, count: 39, class_loss = 0.087216, iou_loss = 0.433584, total_loss = 0.520800
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.759160, GIOU: 0.746583), Class: 0.992014, Obj: 0.735484, No Obj: 0.002114, .5R: 0.928205, .75R: 0.605128, count: 195, class_loss = 0.876046, iou_loss = 24.311687, total_loss = 25.187735
#  total_bbox = 1528571, rewritten_bbox = 0.988374 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5392: 0.481849, 0.718443 avg loss, 0.000261 rate, 1.162076 seconds, 345088 images, 0.275745 hours left
# Loaded: 0.000036 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.816847, GIOU: 0.811774), Class: 0.988333, Obj: 0.663093, No Obj: 0.002261, .5R: 1.000000, .75R: 0.763636, count: 55, class_loss = 0.263296, iou_loss = 0.604546, total_loss = 0.867842
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.779476, GIOU: 0.770054), Class: 0.986799, Obj: 0.710135, No Obj: 0.002425, .5R: 0.964444, .75R: 0.675556, count: 225, class_loss = 1.097279, iou_loss = 28.611067, total_loss = 29.708345
#  total_bbox = 1528851, rewritten_bbox = 0.988193 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5393: 0.680508, 0.714649 avg loss, 0.000261 rate, 1.132758 seconds, 345152 images, 0.274950 hours left
# Loaded: 0.000085 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.846447, GIOU: 0.841886), Class: 0.990901, Obj: 0.801414, No Obj: 0.001986, .5R: 1.000000, .75R: 0.921053, count: 38, class_loss = 0.149450, iou_loss = 0.413745, total_loss = 0.563194
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.778188, GIOU: 0.767031), Class: 0.979144, Obj: 0.745611, No Obj: 0.002530, .5R: 0.946939, .75R: 0.702041, count: 245, class_loss = 0.928281, iou_loss = 35.215347, total_loss = 36.143627
#  total_bbox = 1529134, rewritten_bbox = 0.988076 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5394: 0.539070, 0.697091 avg loss, 0.000261 rate, 1.141710 seconds, 345216 images, 0.274110 hours left
# Loaded: 0.000040 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.787212, GIOU: 0.782857), Class: 0.958555, Obj: 0.720745, No Obj: 0.001840, .5R: 0.947368, .75R: 0.789474, count: 38, class_loss = 0.204392, iou_loss = 0.393211, total_loss = 0.597603
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.751704, GIOU: 0.738175), Class: 0.962693, Obj: 0.669790, No Obj: 0.002838, .5R: 0.909420, .75R: 0.630435, count: 276, class_loss = 1.393728, iou_loss = 36.049515, total_loss = 37.443245
#  total_bbox = 1529448, rewritten_bbox = 0.988069 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5395: 0.799312, 0.707314 avg loss, 0.000261 rate, 1.172301 seconds, 345280 images, 0.273291 hours left
# Loaded: 0.000088 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.826918, GIOU: 0.821458), Class: 0.999068, Obj: 0.804267, No Obj: 0.001589, .5R: 1.000000, .75R: 0.838710, count: 31, class_loss = 0.113105, iou_loss = 0.340173, total_loss = 0.453278
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.696290, GIOU: 0.678094), Class: 0.969072, Obj: 0.657607, No Obj: 0.002532, .5R: 0.845018, .75R: 0.523985, count: 271, class_loss = 1.505536, iou_loss = 38.384377, total_loss = 39.889912
#  total_bbox = 1529750, rewritten_bbox = 0.988070 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5396: 0.809581, 0.717540 avg loss, 0.000261 rate, 1.162377 seconds, 345344 images, 0.272529 hours left
# Loaded: 0.000058 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.853853, GIOU: 0.849760), Class: 0.998177, Obj: 0.781214, No Obj: 0.001292, .5R: 1.000000, .75R: 0.923077, count: 26, class_loss = 0.095877, iou_loss = 0.302020, total_loss = 0.397898
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.773832, GIOU: 0.765074), Class: 0.977584, Obj: 0.725252, No Obj: 0.002189, .5R: 0.942857, .75R: 0.690476, count: 210, class_loss = 1.014134, iou_loss = 28.922985, total_loss = 29.937119
#  total_bbox = 1529986, rewritten_bbox = 0.987918 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5397: 0.555210, 0.701307 avg loss, 0.000261 rate, 1.138169 seconds, 345408 images, 0.271754 hours left
# Loaded: 0.000077 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.786436, GIOU: 0.779243), Class: 0.970141, Obj: 0.527446, No Obj: 0.001690, .5R: 0.941177, .75R: 0.784314, count: 51, class_loss = 0.416255, iou_loss = 0.495816, total_loss = 0.912071
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.774788, GIOU: 0.764829), Class: 0.984689, Obj: 0.745765, No Obj: 0.002386, .5R: 0.931818, .75R: 0.672727, count: 220, class_loss = 0.979504, iou_loss = 28.422567, total_loss = 29.402071
#  total_bbox = 1530257, rewritten_bbox = 0.987808 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5398: 0.698119, 0.700988 avg loss, 0.000261 rate, 1.163172 seconds, 345472 images, 0.270943 hours left
# Loaded: 0.000035 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.749745, GIOU: 0.737673), Class: 0.950147, Obj: 0.558382, No Obj: 0.001729, .5R: 0.978261, .75R: 0.608696, count: 46, class_loss = 0.291329, iou_loss = 0.397810, total_loss = 0.689139
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.761938, GIOU: 0.750075), Class: 0.968545, Obj: 0.649074, No Obj: 0.002970, .5R: 0.922261, .75R: 0.667845, count: 283, class_loss = 1.613501, iou_loss = 34.202736, total_loss = 35.816238
#  total_bbox = 1530586, rewritten_bbox = 0.987726 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5399: 0.952682, 0.726158 avg loss, 0.000261 rate, 1.156460 seconds, 345536 images, 0.270179 hours left
# Loaded: 0.000079 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.827247, GIOU: 0.821624), Class: 0.994900, Obj: 0.793915, No Obj: 0.001601, .5R: 1.000000, .75R: 0.838710, count: 31, class_loss = 0.082827, iou_loss = 0.396711, total_loss = 0.479538
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.778877, GIOU: 0.767663), Class: 0.978627, Obj: 0.753654, No Obj: 0.002830, .5R: 0.944030, .75R: 0.708955, count: 268, class_loss = 1.070759, iou_loss = 37.586418, total_loss = 38.657177
#  total_bbox = 1530885, rewritten_bbox = 0.987664 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5400: 0.577008, 0.711243 avg loss, 0.000026 rate, 1.146821 seconds, 345600 images, 0.269408 hours left
# Saving weights to backup//yolo-obj_last.weights
# Loaded: 0.000047 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.804932, GIOU: 0.797953), Class: 0.999447, Obj: 0.891105, No Obj: 0.001632, .5R: 0.962963, .75R: 0.814815, count: 27, class_loss = 0.063377, iou_loss = 0.302393, total_loss = 0.365770
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.763182, GIOU: 0.752295), Class: 0.981479, Obj: 0.723215, No Obj: 0.002753, .5R: 0.926357, .75R: 0.658915, count: 258, class_loss = 1.156005, iou_loss = 33.147518, total_loss = 34.303524
#  total_bbox = 1531170, rewritten_bbox = 0.987676 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5401: 0.609927, 0.701111 avg loss, 0.000026 rate, 1.058229 seconds, 345664 images, 0.268625 hours left
# Loaded: 0.000037 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.790482, GIOU: 0.784509), Class: 0.972442, Obj: 0.615973, No Obj: 0.001887, .5R: 0.975000, .75R: 0.650000, count: 40, class_loss = 0.285374, iou_loss = 0.402354, total_loss = 0.687728
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.754413, GIOU: 0.740557), Class: 0.982062, Obj: 0.669277, No Obj: 0.002687, .5R: 0.929368, .75R: 0.639405, count: 269, class_loss = 1.452988, iou_loss = 32.139580, total_loss = 33.592567
#  total_bbox = 1531479, rewritten_bbox = 0.987477 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5402: 0.869430, 0.717943 avg loss, 0.000026 rate, 1.148636 seconds, 345728 images, 0.267700 hours left
# Loaded: 0.000043 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.799062, GIOU: 0.792760), Class: 0.972496, Obj: 0.753591, No Obj: 0.001692, .5R: 0.948718, .75R: 0.743590, count: 39, class_loss = 0.142818, iou_loss = 0.462985, total_loss = 0.605803
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.770952, GIOU: 0.760995), Class: 0.984554, Obj: 0.727879, No Obj: 0.002462, .5R: 0.941441, .75R: 0.648649, count: 222, class_loss = 1.088535, iou_loss = 32.052780, total_loss = 33.141315
#  total_bbox = 1531740, rewritten_bbox = 0.987374 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5403: 0.615912, 0.707740 avg loss, 0.000026 rate, 1.173769 seconds, 345792 images, 0.266931 hours left
# Loaded: 0.000056 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.836669, GIOU: 0.830352), Class: 0.999161, Obj: 0.864206, No Obj: 0.001531, .5R: 0.966667, .75R: 0.933333, count: 30, class_loss = 0.051793, iou_loss = 0.338538, total_loss = 0.390332
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.763017, GIOU: 0.749804), Class: 0.971218, Obj: 0.695722, No Obj: 0.002468, .5R: 0.935897, .75R: 0.636752, count: 234, class_loss = 1.125100, iou_loss = 33.590622, total_loss = 34.715721
#  total_bbox = 1532004, rewritten_bbox = 0.987269 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5404: 0.588666, 0.695833 avg loss, 0.000026 rate, 1.127987 seconds, 345856 images, 0.266208 hours left
# Loaded: 0.000039 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.759796, GIOU: 0.750636), Class: 0.948620, Obj: 0.607586, No Obj: 0.001557, .5R: 0.894737, .75R: 0.684211, count: 38, class_loss = 0.254450, iou_loss = 0.376457, total_loss = 0.630907
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.735884, GIOU: 0.720786), Class: 0.966257, Obj: 0.686719, No Obj: 0.002420, .5R: 0.897872, .75R: 0.625532, count: 235, class_loss = 1.328275, iou_loss = 36.650093, total_loss = 37.978367
#  total_bbox = 1532277, rewritten_bbox = 0.987289 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5405: 0.791638, 0.705413 avg loss, 0.000026 rate, 1.141664 seconds, 345920 images, 0.265413 hours left
# Loaded: 0.000041 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.785506, GIOU: 0.780007), Class: 0.996376, Obj: 0.604951, No Obj: 0.001321, .5R: 0.921053, .75R: 0.710526, count: 38, class_loss = 0.207201, iou_loss = 0.413022, total_loss = 0.620223
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.747576, GIOU: 0.736248), Class: 0.977722, Obj: 0.715280, No Obj: 0.002365, .5R: 0.922374, .75R: 0.630137, count: 219, class_loss = 1.099256, iou_loss = 29.444925, total_loss = 30.544182
#  total_bbox = 1532534, rewritten_bbox = 0.987384 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5406: 0.653484, 0.700220 avg loss, 0.000026 rate, 1.158911 seconds, 345984 images, 0.264646 hours left
# Loaded: 0.000043 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.767055, GIOU: 0.753212), Class: 0.976792, Obj: 0.578727, No Obj: 0.001814, .5R: 0.934783, .75R: 0.739130, count: 46, class_loss = 0.318284, iou_loss = 0.447117, total_loss = 0.765401
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.717014, GIOU: 0.696791), Class: 0.953385, Obj: 0.666138, No Obj: 0.002830, .5R: 0.846667, .75R: 0.576667, count: 300, class_loss = 1.721880, iou_loss = 39.271008, total_loss = 40.992886
#  total_bbox = 1532880, rewritten_bbox = 0.987618 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5407: 1.020364, 0.732235 avg loss, 0.000026 rate, 1.174845 seconds, 346048 images, 0.263912 hours left
# Loaded: 0.000035 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.805136, GIOU: 0.800335), Class: 0.967181, Obj: 0.746120, No Obj: 0.002558, .5R: 0.967742, .75R: 0.741935, count: 62, class_loss = 0.253594, iou_loss = 0.648435, total_loss = 0.902029
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.739581, GIOU: 0.726053), Class: 0.972532, Obj: 0.665301, No Obj: 0.002585, .5R: 0.898496, .75R: 0.586466, count: 266, class_loss = 1.385800, iou_loss = 44.399761, total_loss = 45.785561
#  total_bbox = 1533208, rewritten_bbox = 0.987537 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5408: 0.819946, 0.741006 avg loss, 0.000026 rate, 1.168600 seconds, 346112 images, 0.263208 hours left
# Loaded: 0.000049 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.771990, GIOU: 0.766122), Class: 0.983824, Obj: 0.612025, No Obj: 0.001420, .5R: 1.000000, .75R: 0.655172, count: 29, class_loss = 0.197628, iou_loss = 0.292118, total_loss = 0.489746
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.780998, GIOU: 0.770489), Class: 0.987041, Obj: 0.709264, No Obj: 0.002494, .5R: 0.956332, .75R: 0.711790, count: 229, class_loss = 1.017054, iou_loss = 30.979256, total_loss = 31.996309
#  total_bbox = 1533466, rewritten_bbox = 0.987371 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5409: 0.607586, 0.727664 avg loss, 0.000026 rate, 1.161053 seconds, 346176 images, 0.262498 hours left
# Loaded: 0.000037 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.837442, GIOU: 0.834400), Class: 0.995497, Obj: 0.895074, No Obj: 0.001591, .5R: 1.000000, .75R: 0.862069, count: 29, class_loss = 0.088273, iou_loss = 0.328124, total_loss = 0.416397
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.792668, GIOU: 0.785596), Class: 0.984006, Obj: 0.733531, No Obj: 0.002359, .5R: 0.953488, .75R: 0.725581, count: 215, class_loss = 0.886619, iou_loss = 28.682810, total_loss = 29.569429
#  total_bbox = 1533710, rewritten_bbox = 0.987214 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5410: 0.487648, 0.703662 avg loss, 0.000026 rate, 1.137503 seconds, 346240 images, 0.261779 hours left
# Loaded: 0.000048 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.838037, GIOU: 0.834087), Class: 0.980060, Obj: 0.863006, No Obj: 0.002509, .5R: 1.000000, .75R: 0.857143, count: 49, class_loss = 0.091591, iou_loss = 0.505716, total_loss = 0.597307
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.773566, GIOU: 0.759754), Class: 0.969050, Obj: 0.731806, No Obj: 0.002076, .5R: 0.928962, .75R: 0.704918, count: 183, class_loss = 0.922732, iou_loss = 24.710573, total_loss = 25.633305
#  total_bbox = 1533942, rewritten_bbox = 0.987130 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5411: 0.507374, 0.684033 avg loss, 0.000026 rate, 1.150860 seconds, 346304 images, 0.261026 hours left
# Loaded: 0.000037 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.790814, GIOU: 0.780508), Class: 0.966540, Obj: 0.667062, No Obj: 0.002342, .5R: 0.967742, .75R: 0.709677, count: 62, class_loss = 0.347325, iou_loss = 0.677843, total_loss = 1.025168
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.715024, GIOU: 0.695753), Class: 0.973631, Obj: 0.701689, No Obj: 0.002521, .5R: 0.862500, .75R: 0.562500, count: 240, class_loss = 1.375380, iou_loss = 33.575554, total_loss = 34.950935
#  total_bbox = 1534244, rewritten_bbox = 0.987327 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5412: 0.861623, 0.701792 avg loss, 0.000026 rate, 1.133737 seconds, 346368 images, 0.260299 hours left
# Loaded: 0.000042 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.844875, GIOU: 0.841500), Class: 0.995054, Obj: 0.866917, No Obj: 0.001934, .5R: 1.000000, .75R: 0.843750, count: 32, class_loss = 0.084634, iou_loss = 0.405868, total_loss = 0.490502
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.776813, GIOU: 0.765803), Class: 0.961076, Obj: 0.731496, No Obj: 0.002187, .5R: 0.958763, .75R: 0.690722, count: 194, class_loss = 0.982497, iou_loss = 26.985077, total_loss = 27.967575
#  total_bbox = 1534470, rewritten_bbox = 0.987181 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5413: 0.533773, 0.684990 avg loss, 0.000026 rate, 1.145177 seconds, 346432 images, 0.259547 hours left
# Loaded: 0.000040 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.818471, GIOU: 0.810030), Class: 0.997638, Obj: 0.814587, No Obj: 0.001770, .5R: 0.972222, .75R: 0.888889, count: 36, class_loss = 0.109537, iou_loss = 0.417448, total_loss = 0.526985
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.761010, GIOU: 0.748776), Class: 0.990735, Obj: 0.764035, No Obj: 0.002518, .5R: 0.919492, .75R: 0.614407, count: 236, class_loss = 0.857737, iou_loss = 31.530699, total_loss = 32.388435
#  total_bbox = 1534742, rewritten_bbox = 0.987137 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5414: 0.483867, 0.664878 avg loss, 0.000026 rate, 1.151292 seconds, 346496 images, 0.258819 hours left
# Loaded: 0.000051 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.812572, GIOU: 0.806220), Class: 0.998221, Obj: 0.794747, No Obj: 0.001448, .5R: 0.965517, .75R: 0.827586, count: 29, class_loss = 0.100111, iou_loss = 0.303805, total_loss = 0.403916
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.751910, GIOU: 0.735982), Class: 0.978604, Obj: 0.705080, No Obj: 0.002402, .5R: 0.899582, .75R: 0.644351, count: 239, class_loss = 1.212907, iou_loss = 34.817383, total_loss = 36.030289
#  total_bbox = 1535010, rewritten_bbox = 0.987290 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5415: 0.656748, 0.664065 avg loss, 0.000026 rate, 1.154134 seconds, 346560 images, 0.258105 hours left
# Loaded: 0.000079 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.819587, GIOU: 0.813613), Class: 0.976086, Obj: 0.685688, No Obj: 0.002344, .5R: 0.964286, .75R: 0.857143, count: 56, class_loss = 0.250892, iou_loss = 0.607607, total_loss = 0.858499
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.714854, GIOU: 0.698547), Class: 0.965859, Obj: 0.680777, No Obj: 0.002415, .5R: 0.840000, .75R: 0.568000, count: 250, class_loss = 1.312024, iou_loss = 36.590374, total_loss = 37.902397
#  total_bbox = 1535316, rewritten_bbox = 0.987289 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5416: 0.781712, 0.675830 avg loss, 0.000026 rate, 1.157612 seconds, 346624 images, 0.257400 hours left
# Loaded: 0.000037 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.806402, GIOU: 0.800742), Class: 0.971688, Obj: 0.718690, No Obj: 0.001460, .5R: 1.000000, .75R: 0.750000, count: 24, class_loss = 0.148226, iou_loss = 0.223173, total_loss = 0.371399
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.757864, GIOU: 0.744843), Class: 0.967677, Obj: 0.744529, No Obj: 0.002347, .5R: 0.933036, .75R: 0.656250, count: 224, class_loss = 1.025914, iou_loss = 31.669926, total_loss = 32.695839
#  total_bbox = 1535564, rewritten_bbox = 0.987259 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5417: 0.587308, 0.666978 avg loss, 0.000026 rate, 1.142014 seconds, 346688 images, 0.256704 hours left
# Loaded: 0.000039 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.810662, GIOU: 0.802713), Class: 0.995117, Obj: 0.704824, No Obj: 0.001450, .5R: 1.000000, .75R: 0.720000, count: 25, class_loss = 0.119998, iou_loss = 0.301518, total_loss = 0.421516
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.791977, GIOU: 0.782949), Class: 0.985700, Obj: 0.752940, No Obj: 0.002803, .5R: 0.971545, .75R: 0.743902, count: 246, class_loss = 0.997755, iou_loss = 32.900234, total_loss = 33.897987
#  total_bbox = 1535835, rewritten_bbox = 0.987085 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5418: 0.559093, 0.656189 avg loss, 0.000026 rate, 1.159338 seconds, 346752 images, 0.255986 hours left
# Loaded: 0.000066 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.828424, GIOU: 0.823710), Class: 0.997066, Obj: 0.684540, No Obj: 0.002027, .5R: 1.000000, .75R: 0.883721, count: 43, class_loss = 0.180546, iou_loss = 0.428772, total_loss = 0.609318
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.748478, GIOU: 0.733944), Class: 0.963652, Obj: 0.671148, No Obj: 0.002682, .5R: 0.914729, .75R: 0.616279, count: 258, class_loss = 1.559014, iou_loss = 35.713440, total_loss = 37.272453
#  total_bbox = 1536136, rewritten_bbox = 0.986957 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5419: 0.870011, 0.677571 avg loss, 0.000026 rate, 1.164420 seconds, 346816 images, 0.255301 hours left
# Loaded: 0.000310 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.827680, GIOU: 0.822298), Class: 0.990692, Obj: 0.762716, No Obj: 0.002081, .5R: 1.000000, .75R: 0.866667, count: 45, class_loss = 0.151221, iou_loss = 0.505335, total_loss = 0.656556
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.757789, GIOU: 0.744413), Class: 0.957534, Obj: 0.730842, No Obj: 0.002471, .5R: 0.937500, .75R: 0.670833, count: 240, class_loss = 1.081203, iou_loss = 38.085979, total_loss = 39.167183
#  total_bbox = 1536421, rewritten_bbox = 0.986969 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5420: 0.616438, 0.671458 avg loss, 0.000026 rate, 1.141082 seconds, 346880 images, 0.254627 hours left
# Loaded: 0.000036 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.809808, GIOU: 0.803994), Class: 0.994844, Obj: 0.689683, No Obj: 0.001482, .5R: 1.000000, .75R: 0.764706, count: 34, class_loss = 0.161030, iou_loss = 0.364367, total_loss = 0.525397
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.764932, GIOU: 0.754838), Class: 0.970824, Obj: 0.712460, No Obj: 0.002585, .5R: 0.958647, .75R: 0.657895, count: 266, class_loss = 1.200005, iou_loss = 35.724926, total_loss = 36.924931
#  total_bbox = 1536721, rewritten_bbox = 0.986972 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5421: 0.680750, 0.672387 avg loss, 0.000026 rate, 1.163526 seconds, 346944 images, 0.253920 hours left
# Loaded: 0.000040 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.817137, GIOU: 0.813203), Class: 0.982533, Obj: 0.806942, No Obj: 0.001571, .5R: 0.968750, .75R: 0.781250, count: 32, class_loss = 0.110309, iou_loss = 0.414049, total_loss = 0.524358
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.734699, GIOU: 0.720187), Class: 0.971382, Obj: 0.646659, No Obj: 0.002637, .5R: 0.913726, .75R: 0.572549, count: 255, class_loss = 1.623196, iou_loss = 35.049759, total_loss = 36.672955
#  total_bbox = 1537008, rewritten_bbox = 0.986917 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5422: 0.866997, 0.691848 avg loss, 0.000026 rate, 1.170019 seconds, 347008 images, 0.253252 hours left
# Loaded: 0.000052 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.820043, GIOU: 0.817023), Class: 0.993121, Obj: 0.835976, No Obj: 0.001973, .5R: 0.975610, .75R: 0.853658, count: 41, class_loss = 0.097352, iou_loss = 0.457725, total_loss = 0.555077
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.774162, GIOU: 0.763565), Class: 0.979046, Obj: 0.702943, No Obj: 0.002369, .5R: 0.959641, .75R: 0.681614, count: 223, class_loss = 1.085269, iou_loss = 24.342779, total_loss = 25.428047
#  total_bbox = 1537272, rewritten_bbox = 0.986748 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5423: 0.591532, 0.681817 avg loss, 0.000026 rate, 1.152702 seconds, 347072 images, 0.252598 hours left
# Loaded: 0.000036 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.808483, GIOU: 0.802149), Class: 0.985098, Obj: 0.681354, No Obj: 0.002230, .5R: 0.981481, .75R: 0.759259, count: 54, class_loss = 0.252739, iou_loss = 0.603498, total_loss = 0.856237
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.780758, GIOU: 0.770678), Class: 0.975794, Obj: 0.725166, No Obj: 0.002866, .5R: 0.941818, .75R: 0.720000, count: 275, class_loss = 1.273127, iou_loss = 34.369888, total_loss = 35.643017
#  total_bbox = 1537601, rewritten_bbox = 0.986602 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5424: 0.763158, 0.689951 avg loss, 0.000026 rate, 1.146433 seconds, 347136 images, 0.251920 hours left
# Loaded: 0.000035 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.786389, GIOU: 0.774647), Class: 0.976911, Obj: 0.598009, No Obj: 0.001919, .5R: 0.953488, .75R: 0.767442, count: 43, class_loss = 0.258606, iou_loss = 0.432486, total_loss = 0.691092
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.757271, GIOU: 0.745045), Class: 0.972427, Obj: 0.689371, No Obj: 0.002711, .5R: 0.937743, .75R: 0.649805, count: 257, class_loss = 1.345936, iou_loss = 32.658062, total_loss = 34.003998
#  total_bbox = 1537901, rewritten_bbox = 0.986474 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5425: 0.802521, 0.701208 avg loss, 0.000026 rate, 1.147021 seconds, 347200 images, 0.251235 hours left
# Loaded: 0.000047 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.834018, GIOU: 0.830167), Class: 0.989492, Obj: 0.803692, No Obj: 0.001982, .5R: 1.000000, .75R: 0.883721, count: 43, class_loss = 0.133248, iou_loss = 0.498317, total_loss = 0.631566
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.727196, GIOU: 0.710882), Class: 0.945824, Obj: 0.682363, No Obj: 0.002644, .5R: 0.870445, .75R: 0.574899, count: 247, class_loss = 1.494445, iou_loss = 36.550186, total_loss = 38.044632
#  total_bbox = 1538191, rewritten_bbox = 0.986548 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5426: 0.814087, 0.712496 avg loss, 0.000026 rate, 1.150664 seconds, 347264 images, 0.250555 hours left
# Loaded: 0.000060 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.815553, GIOU: 0.809689), Class: 0.965824, Obj: 0.703155, No Obj: 0.002168, .5R: 1.000000, .75R: 0.784314, count: 51, class_loss = 0.268373, iou_loss = 0.526835, total_loss = 0.795209
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.757988, GIOU: 0.745268), Class: 0.962102, Obj: 0.712869, No Obj: 0.001985, .5R: 0.926136, .75R: 0.630682, count: 176, class_loss = 0.967330, iou_loss = 22.084629, total_loss = 23.051960
#  total_bbox = 1538418, rewritten_bbox = 0.986533 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5427: 0.618085, 0.703055 avg loss, 0.000026 rate, 1.168341 seconds, 347328 images, 0.249884 hours left
# Loaded: 0.000047 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.812561, GIOU: 0.805296), Class: 0.977036, Obj: 0.658520, No Obj: 0.001919, .5R: 1.000000, .75R: 0.787234, count: 47, class_loss = 0.240356, iou_loss = 0.534235, total_loss = 0.774591
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.784913, GIOU: 0.774930), Class: 0.985148, Obj: 0.735467, No Obj: 0.002351, .5R: 0.953052, .75R: 0.713615, count: 213, class_loss = 0.956916, iou_loss = 27.430740, total_loss = 28.387655
#  total_bbox = 1538678, rewritten_bbox = 0.986366 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5428: 0.598856, 0.692635 avg loss, 0.000026 rate, 1.131586 seconds, 347392 images, 0.249245 hours left
# Loaded: 0.000041 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.796694, GIOU: 0.791943), Class: 0.994974, Obj: 0.651462, No Obj: 0.001653, .5R: 0.950000, .75R: 0.725000, count: 40, class_loss = 0.201706, iou_loss = 0.446243, total_loss = 0.647949
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.761056, GIOU: 0.748662), Class: 0.966380, Obj: 0.656951, No Obj: 0.002744, .5R: 0.923913, .75R: 0.641304, count: 276, class_loss = 1.545500, iou_loss = 41.172600, total_loss = 42.718098
#  total_bbox = 1538994, rewritten_bbox = 0.986164 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5429: 0.873845, 0.710756 avg loss, 0.000026 rate, 1.144482 seconds, 347456 images, 0.248550 hours left
# Loaded: 0.000062 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.815106, GIOU: 0.809877), Class: 0.964853, Obj: 0.721792, No Obj: 0.002078, .5R: 1.000000, .75R: 0.717391, count: 46, class_loss = 0.241459, iou_loss = 0.587086, total_loss = 0.828544
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.734821, GIOU: 0.720747), Class: 0.978605, Obj: 0.696272, No Obj: 0.002361, .5R: 0.894737, .75R: 0.578947, count: 228, class_loss = 1.176912, iou_loss = 32.369667, total_loss = 33.546577
#  total_bbox = 1539268, rewritten_bbox = 0.986118 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5430: 0.709431, 0.710623 avg loss, 0.000026 rate, 1.138434 seconds, 347520 images, 0.247880 hours left
# Loaded: 0.000059 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.829067, GIOU: 0.822260), Class: 0.969960, Obj: 0.789619, No Obj: 0.001767, .5R: 0.972973, .75R: 0.864865, count: 37, class_loss = 0.168077, iou_loss = 0.364017, total_loss = 0.532094
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.729499, GIOU: 0.713957), Class: 0.959721, Obj: 0.681687, No Obj: 0.002808, .5R: 0.894198, .75R: 0.610922, count: 293, class_loss = 1.512021, iou_loss = 36.851757, total_loss = 38.363777
#  total_bbox = 1539598, rewritten_bbox = 0.986361 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5431: 0.840290, 0.723590 avg loss, 0.000026 rate, 1.138195 seconds, 347584 images, 0.247204 hours left
# Loaded: 0.000036 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.810280, GIOU: 0.804942), Class: 0.991556, Obj: 0.674274, No Obj: 0.002030, .5R: 0.951219, .75R: 0.804878, count: 41, class_loss = 0.237516, iou_loss = 0.477126, total_loss = 0.714642
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.756457, GIOU: 0.744885), Class: 0.965079, Obj: 0.704512, No Obj: 0.002586, .5R: 0.932203, .75R: 0.639831, count: 236, class_loss = 1.307840, iou_loss = 33.116337, total_loss = 34.424175
#  total_bbox = 1539875, rewritten_bbox = 0.986249 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5432: 0.772915, 0.728522 avg loss, 0.000026 rate, 1.132277 seconds, 347648 images, 0.246531 hours left
# Loaded: 0.000038 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.787134, GIOU: 0.781750), Class: 0.977470, Obj: 0.560408, No Obj: 0.001317, .5R: 1.000000, .75R: 0.606061, count: 33, class_loss = 0.221029, iou_loss = 0.312952, total_loss = 0.533981
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.735757, GIOU: 0.719588), Class: 0.963685, Obj: 0.682916, No Obj: 0.002669, .5R: 0.896797, .75R: 0.587189, count: 281, class_loss = 1.455936, iou_loss = 39.846622, total_loss = 41.302559
#  total_bbox = 1540189, rewritten_bbox = 0.986243 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5433: 0.838744, 0.739545 avg loss, 0.000026 rate, 1.145608 seconds, 347712 images, 0.245852 hours left
# Loaded: 0.000068 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.792535, GIOU: 0.785225), Class: 0.942006, Obj: 0.662554, No Obj: 0.001351, .5R: 1.000000, .75R: 0.708333, count: 24, class_loss = 0.197957, iou_loss = 0.212800, total_loss = 0.410757
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.769874, GIOU: 0.758080), Class: 0.963913, Obj: 0.698456, No Obj: 0.002530, .5R: 0.949791, .75R: 0.661088, count: 239, class_loss = 1.186317, iou_loss = 28.679888, total_loss = 29.866205
#  total_bbox = 1540452, rewritten_bbox = 0.986139 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5434: 0.692376, 0.734828 avg loss, 0.000026 rate, 1.137660 seconds, 347776 images, 0.245198 hours left
# Loaded: 0.000036 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.828838, GIOU: 0.824978), Class: 0.998836, Obj: 0.828614, No Obj: 0.001740, .5R: 1.000000, .75R: 0.914286, count: 35, class_loss = 0.069997, iou_loss = 0.404317, total_loss = 0.474314
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.721271, GIOU: 0.704437), Class: 0.971816, Obj: 0.672091, No Obj: 0.002827, .5R: 0.883392, .75R: 0.593640, count: 283, class_loss = 1.655557, iou_loss = 44.094761, total_loss = 45.750317
#  total_bbox = 1540770, rewritten_bbox = 0.986325 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5435: 0.863023, 0.747647 avg loss, 0.000026 rate, 1.164754 seconds, 347840 images, 0.244535 hours left
# Loaded: 0.000040 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.813028, GIOU: 0.807884), Class: 0.962950, Obj: 0.721919, No Obj: 0.001626, .5R: 1.000000, .75R: 0.769231, count: 39, class_loss = 0.190803, iou_loss = 0.443584, total_loss = 0.634387
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.764089, GIOU: 0.755220), Class: 0.970516, Obj: 0.669217, No Obj: 0.002400, .5R: 0.930328, .75R: 0.659836, count: 244, class_loss = 1.293051, iou_loss = 38.478424, total_loss = 39.771477
#  total_bbox = 1541053, rewritten_bbox = 0.986209 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5436: 0.742158, 0.747098 avg loss, 0.000026 rate, 1.133474 seconds, 347904 images, 0.243918 hours left
# Loaded: 0.000033 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.749620, GIOU: 0.735645), Class: 0.965066, Obj: 0.519052, No Obj: 0.002043, .5R: 0.933333, .75R: 0.633333, count: 60, class_loss = 0.471237, iou_loss = 0.592656, total_loss = 1.063893
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.754497, GIOU: 0.739996), Class: 0.978480, Obj: 0.767819, No Obj: 0.002518, .5R: 0.910638, .75R: 0.676596, count: 235, class_loss = 0.947454, iou_loss = 29.866440, total_loss = 30.813894
#  total_bbox = 1541348, rewritten_bbox = 0.986409 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5437: 0.709617, 0.743350 avg loss, 0.000026 rate, 1.145519 seconds, 347968 images, 0.243255 hours left
# Loaded: 0.000041 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.800884, GIOU: 0.792845), Class: 0.975959, Obj: 0.667807, No Obj: 0.001967, .5R: 1.000000, .75R: 0.693878, count: 49, class_loss = 0.239153, iou_loss = 0.461677, total_loss = 0.700830
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.783381, GIOU: 0.772514), Class: 0.978890, Obj: 0.718279, No Obj: 0.002423, .5R: 0.949772, .75R: 0.739726, count: 219, class_loss = 1.159373, iou_loss = 27.280151, total_loss = 28.439524
#  total_bbox = 1541616, rewritten_bbox = 0.986303 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5438: 0.699490, 0.738964 avg loss, 0.000026 rate, 1.155597 seconds, 348032 images, 0.242614 hours left
# Loaded: 0.000043 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.807677, GIOU: 0.801359), Class: 0.987128, Obj: 0.653109, No Obj: 0.001748, .5R: 1.000000, .75R: 0.783784, count: 37, class_loss = 0.187356, iou_loss = 0.373664, total_loss = 0.561020
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.729158, GIOU: 0.713326), Class: 0.973769, Obj: 0.699852, No Obj: 0.002626, .5R: 0.915058, .75R: 0.583012, count: 259, class_loss = 1.384488, iou_loss = 40.057011, total_loss = 41.441498
#  total_bbox = 1541912, rewritten_bbox = 0.986438 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5439: 0.786176, 0.743685 avg loss, 0.000026 rate, 1.146227 seconds, 348096 images, 0.241991 hours left
# Loaded: 0.000035 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.788086, GIOU: 0.781923), Class: 0.992640, Obj: 0.598766, No Obj: 0.002140, .5R: 1.000000, .75R: 0.736842, count: 57, class_loss = 0.333687, iou_loss = 0.619065, total_loss = 0.952751
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.763484, GIOU: 0.748578), Class: 0.965920, Obj: 0.726785, No Obj: 0.002497, .5R: 0.931818, .75R: 0.681818, count: 220, class_loss = 1.230996, iou_loss = 28.481333, total_loss = 29.712328
#  total_bbox = 1542189, rewritten_bbox = 0.986325 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5440: 0.782586, 0.747575 avg loss, 0.000026 rate, 1.141526 seconds, 348160 images, 0.241358 hours left
# Loaded: 0.000039 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.833627, GIOU: 0.830104), Class: 0.999099, Obj: 0.839059, No Obj: 0.001424, .5R: 1.000000, .75R: 0.791667, count: 24, class_loss = 0.082838, iou_loss = 0.333625, total_loss = 0.416463
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.761418, GIOU: 0.749965), Class: 0.971870, Obj: 0.738143, No Obj: 0.002911, .5R: 0.911348, .75R: 0.702128, count: 282, class_loss = 1.349325, iou_loss = 35.094017, total_loss = 36.443340
#  total_bbox = 1542495, rewritten_bbox = 0.986454 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5441: 0.716303, 0.744448 avg loss, 0.000026 rate, 1.152341 seconds, 348224 images, 0.240720 hours left
# Loaded: 0.000038 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.852896, GIOU: 0.850780), Class: 0.992533, Obj: 0.897501, No Obj: 0.001950, .5R: 1.000000, .75R: 0.904762, count: 42, class_loss = 0.056928, iou_loss = 0.576141, total_loss = 0.633069
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.762531, GIOU: 0.751232), Class: 0.958916, Obj: 0.733899, No Obj: 0.002882, .5R: 0.928082, .75R: 0.671233, count: 292, class_loss = 1.284407, iou_loss = 41.033039, total_loss = 42.317448
#  total_bbox = 1542829, rewritten_bbox = 0.986824 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5442: 0.670878, 0.737091 avg loss, 0.000026 rate, 1.148846 seconds, 348288 images, 0.240102 hours left
# Loaded: 0.000041 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.836723, GIOU: 0.833324), Class: 0.973830, Obj: 0.793776, No Obj: 0.001871, .5R: 1.000000, .75R: 0.818182, count: 44, class_loss = 0.144523, iou_loss = 0.451883, total_loss = 0.596406
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.756941, GIOU: 0.744223), Class: 0.987159, Obj: 0.725901, No Obj: 0.002540, .5R: 0.922449, .75R: 0.644898, count: 245, class_loss = 1.094723, iou_loss = 33.712154, total_loss = 34.806877
#  total_bbox = 1543118, rewritten_bbox = 0.986768 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5443: 0.619845, 0.725367 avg loss, 0.000026 rate, 1.129884 seconds, 348352 images, 0.239482 hours left
# Loaded: 0.000053 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.831598, GIOU: 0.827566), Class: 0.992328, Obj: 0.777386, No Obj: 0.002330, .5R: 0.979592, .75R: 0.857143, count: 49, class_loss = 0.162563, iou_loss = 0.530991, total_loss = 0.693554
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.771770, GIOU: 0.762994), Class: 0.982531, Obj: 0.746529, No Obj: 0.002613, .5R: 0.958333, .75R: 0.655303, count: 264, class_loss = 0.977268, iou_loss = 33.995586, total_loss = 34.972855
#  total_bbox = 1543431, rewritten_bbox = 0.986763 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5444: 0.570133, 0.709843 avg loss, 0.000026 rate, 1.148993 seconds, 348416 images, 0.238836 hours left
# Loaded: 0.000035 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.819975, GIOU: 0.817437), Class: 0.968310, Obj: 0.794933, No Obj: 0.001859, .5R: 1.000000, .75R: 0.823529, count: 34, class_loss = 0.154073, iou_loss = 0.348391, total_loss = 0.502464
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.759082, GIOU: 0.746492), Class: 0.963987, Obj: 0.703181, No Obj: 0.002465, .5R: 0.929752, .75R: 0.619835, count: 242, class_loss = 1.318218, iou_loss = 38.144798, total_loss = 39.463017
#  total_bbox = 1543707, rewritten_bbox = 0.986781 %
#
#  (next mAP calculation at 5606 iterations)
#  Last accuracy mAP@0.5 = 60.03 %, best = 60.03 %
#  5445: 0.736376, 0.712496 avg loss, 0.000026 rate, 1.150855 seconds, 348480 images, 0.238222 hours left
# Loaded: 0.000070 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.810047, GIOU: 0.804335), Class: 0.984239, Obj: 0.689388, No Obj: 0.001556, .5R: 0.970588, .75R: 0.735294, count: 34, class_loss = 0.175133, iou_loss = 0.414650, total_loss = 0.589783
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.754887, GIOU: 0.745495), Class: 0.985676, Obj: 0.677421, No Obj: 0.002487, .5R: 0.924051, .75R: 0.594937, count: 237, class_loss = 1.255209, iou_loss = 35.742466, total_loss = 36.997677
# ...
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.765482, GIOU: 0.752072), Class: 0.962632, Obj: 0.704659, No Obj: 0.002617, .5R: 0.927711, .75R: 0.686747, count: 249, class_loss = 1.362520, iou_loss = 38.678581, total_loss = 40.041100
#  total_bbox = 1696060, rewritten_bbox = 0.984399 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5982: 0.733354, 0.787521 avg loss, 0.000026 rate, 1.153354 seconds, 382848 images, 0.048036 hours left
# Loaded: 0.000058 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.798781, GIOU: 0.788953), Class: 0.980720, Obj: 0.734359, No Obj: 0.001608, .5R: 0.909091, .75R: 0.787879, count: 33, class_loss = 0.133425, iou_loss = 0.408250, total_loss = 0.541676
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.771853, GIOU: 0.760714), Class: 0.951330, Obj: 0.726923, No Obj: 0.002178, .5R: 0.920398, .75R: 0.711443, count: 201, class_loss = 1.168653, iou_loss = 26.981726, total_loss = 28.150379
#  total_bbox = 1696294, rewritten_bbox = 0.984440 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5983: 0.651274, 0.773896 avg loss, 0.000026 rate, 1.129003 seconds, 382912 images, 0.047613 hours left
# Loaded: 0.000054 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.823152, GIOU: 0.815590), Class: 0.989759, Obj: 0.789250, No Obj: 0.001289, .5R: 1.000000, .75R: 0.869565, count: 23, class_loss = 0.114225, iou_loss = 0.267441, total_loss = 0.381666
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.770993, GIOU: 0.761946), Class: 0.974397, Obj: 0.710342, No Obj: 0.002651, .5R: 0.940000, .75R: 0.668000, count: 250, class_loss = 1.157901, iou_loss = 30.906858, total_loss = 32.064758
#  total_bbox = 1696567, rewritten_bbox = 0.984282 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5984: 0.636285, 0.760135 avg loss, 0.000026 rate, 1.141315 seconds, 382976 images, 0.047190 hours left
# Loaded: 0.000082 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.868769, GIOU: 0.866869), Class: 0.997741, Obj: 0.861091, No Obj: 0.001666, .5R: 1.000000, .75R: 1.000000, count: 25, class_loss = 0.074645, iou_loss = 0.290968, total_loss = 0.365613
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.768434, GIOU: 0.755885), Class: 0.933914, Obj: 0.693983, No Obj: 0.002568, .5R: 0.947170, .75R: 0.686792, count: 265, class_loss = 1.553239, iou_loss = 31.964544, total_loss = 33.517784
#  total_bbox = 1696857, rewritten_bbox = 0.984173 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5985: 0.814141, 0.765536 avg loss, 0.000026 rate, 1.161083 seconds, 383040 images, 0.046769 hours left
# Loaded: 0.000041 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.799112, GIOU: 0.790956), Class: 0.989570, Obj: 0.676958, No Obj: 0.001480, .5R: 1.000000, .75R: 0.781250, count: 32, class_loss = 0.170989, iou_loss = 0.326270, total_loss = 0.497258
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.767789, GIOU: 0.756867), Class: 0.983871, Obj: 0.745396, No Obj: 0.002460, .5R: 0.947598, .75R: 0.685590, count: 229, class_loss = 0.987150, iou_loss = 34.881001, total_loss = 35.868149
#  total_bbox = 1697118, rewritten_bbox = 0.984139 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5986: 0.579306, 0.746913 avg loss, 0.000026 rate, 1.152349 seconds, 383104 images, 0.046350 hours left
# Loaded: 0.000043 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.826673, GIOU: 0.816274), Class: 0.962895, Obj: 0.759394, No Obj: 0.002046, .5R: 0.975000, .75R: 0.875000, count: 40, class_loss = 0.154908, iou_loss = 0.471500, total_loss = 0.626408
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.763544, GIOU: 0.752477), Class: 0.985335, Obj: 0.745579, No Obj: 0.002728, .5R: 0.933333, .75R: 0.674510, count: 255, class_loss = 1.101115, iou_loss = 40.547726, total_loss = 41.648842
#  total_bbox = 1697413, rewritten_bbox = 0.984204 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5987: 0.628236, 0.735045 avg loss, 0.000026 rate, 1.151618 seconds, 383168 images, 0.045931 hours left
# Loaded: 0.000043 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.801244, GIOU: 0.795637), Class: 0.972977, Obj: 0.628147, No Obj: 0.002038, .5R: 0.979592, .75R: 0.795918, count: 49, class_loss = 0.268238, iou_loss = 0.471792, total_loss = 0.740030
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.688551, GIOU: 0.664464), Class: 0.965734, Obj: 0.684932, No Obj: 0.002665, .5R: 0.804124, .75R: 0.522337, count: 291, class_loss = 1.535377, iou_loss = 40.424995, total_loss = 41.960373
#  total_bbox = 1697753, rewritten_bbox = 0.984596 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5988: 0.902087, 0.751749 avg loss, 0.000026 rate, 1.142386 seconds, 383232 images, 0.045513 hours left
# Loaded: 0.000036 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.826299, GIOU: 0.821612), Class: 0.998077, Obj: 0.804375, No Obj: 0.001829, .5R: 1.000000, .75R: 0.837838, count: 37, class_loss = 0.118098, iou_loss = 0.373901, total_loss = 0.491999
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.738785, GIOU: 0.722557), Class: 0.969365, Obj: 0.673094, No Obj: 0.003030, .5R: 0.901899, .75R: 0.629747, count: 316, class_loss = 1.689619, iou_loss = 49.999962, total_loss = 51.689579
#  total_bbox = 1698106, rewritten_bbox = 0.984626 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5989: 0.904096, 0.766984 avg loss, 0.000026 rate, 1.174342 seconds, 383296 images, 0.045096 hours left
# Loaded: 0.000037 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.804264, GIOU: 0.795513), Class: 0.993072, Obj: 0.640598, No Obj: 0.001658, .5R: 0.954545, .75R: 0.772727, count: 44, class_loss = 0.215251, iou_loss = 0.507103, total_loss = 0.722355
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.765089, GIOU: 0.752586), Class: 0.980448, Obj: 0.705807, No Obj: 0.002175, .5R: 0.935323, .75R: 0.636816, count: 201, class_loss = 0.917121, iou_loss = 25.982124, total_loss = 26.899244
#  total_bbox = 1698351, rewritten_bbox = 0.984543 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5990: 0.566422, 0.746928 avg loss, 0.000026 rate, 1.158354 seconds, 383360 images, 0.044681 hours left
# Loaded: 0.000057 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.810474, GIOU: 0.805748), Class: 0.978015, Obj: 0.656131, No Obj: 0.001544, .5R: 1.000000, .75R: 0.750000, count: 36, class_loss = 0.159882, iou_loss = 0.413907, total_loss = 0.573789
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.726279, GIOU: 0.710237), Class: 0.980567, Obj: 0.702898, No Obj: 0.003030, .5R: 0.888889, .75R: 0.594771, count: 306, class_loss = 1.447090, iou_loss = 48.944668, total_loss = 50.391758
#  total_bbox = 1698693, rewritten_bbox = 0.984639 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5991: 0.803739, 0.752609 avg loss, 0.000026 rate, 1.160741 seconds, 383424 images, 0.044266 hours left
# Loaded: 0.000044 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.837616, GIOU: 0.833592), Class: 0.978870, Obj: 0.774861, No Obj: 0.001763, .5R: 1.000000, .75R: 0.848485, count: 33, class_loss = 0.105572, iou_loss = 0.417104, total_loss = 0.522676
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.748262, GIOU: 0.735355), Class: 0.985551, Obj: 0.738382, No Obj: 0.002618, .5R: 0.912088, .75R: 0.622711, count: 273, class_loss = 0.970682, iou_loss = 47.449352, total_loss = 48.420033
#  total_bbox = 1698999, rewritten_bbox = 0.984639 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5992: 0.538353, 0.731183 avg loss, 0.000026 rate, 1.146418 seconds, 383488 images, 0.043853 hours left
# Loaded: 0.000034 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.788424, GIOU: 0.776917), Class: 0.958619, Obj: 0.606415, No Obj: 0.001670, .5R: 0.950000, .75R: 0.725000, count: 40, class_loss = 0.254657, iou_loss = 0.357891, total_loss = 0.612548
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.761393, GIOU: 0.748654), Class: 0.973636, Obj: 0.650424, No Obj: 0.002444, .5R: 0.925490, .75R: 0.670588, count: 255, class_loss = 1.429221, iou_loss = 28.698389, total_loss = 30.127611
#  total_bbox = 1699294, rewritten_bbox = 0.984644 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5993: 0.842185, 0.742284 avg loss, 0.000026 rate, 1.162571 seconds, 383552 images, 0.043440 hours left
# Loaded: 0.000043 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.834281, GIOU: 0.830787), Class: 0.994050, Obj: 0.783296, No Obj: 0.001420, .5R: 1.000000, .75R: 0.833333, count: 24, class_loss = 0.100623, iou_loss = 0.289698, total_loss = 0.390321
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.794301, GIOU: 0.787699), Class: 0.977611, Obj: 0.728856, No Obj: 0.002503, .5R: 0.958333, .75R: 0.729167, count: 240, class_loss = 1.036601, iou_loss = 28.072247, total_loss = 29.108849
#  total_bbox = 1699558, rewritten_bbox = 0.984550 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5994: 0.568815, 0.724937 avg loss, 0.000026 rate, 1.158683 seconds, 383616 images, 0.043028 hours left
# Loaded: 0.000052 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.819423, GIOU: 0.810242), Class: 0.962820, Obj: 0.846467, No Obj: 0.001325, .5R: 0.956522, .75R: 0.869565, count: 23, class_loss = 0.087650, iou_loss = 0.269971, total_loss = 0.357621
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.755497, GIOU: 0.744303), Class: 0.969814, Obj: 0.699062, No Obj: 0.002681, .5R: 0.940075, .75R: 0.640449, count: 267, class_loss = 1.372603, iou_loss = 35.353519, total_loss = 36.726124
#  total_bbox = 1699848, rewritten_bbox = 0.984441 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5995: 0.730359, 0.725479 avg loss, 0.000026 rate, 1.146419 seconds, 383680 images, 0.042617 hours left
# Loaded: 0.000036 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.781293, GIOU: 0.770131), Class: 0.970675, Obj: 0.673705, No Obj: 0.001800, .5R: 0.961538, .75R: 0.750000, count: 52, class_loss = 0.288061, iou_loss = 0.539109, total_loss = 0.827171
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.755717, GIOU: 0.743552), Class: 0.964894, Obj: 0.694639, No Obj: 0.002590, .5R: 0.941406, .75R: 0.609375, count: 256, class_loss = 1.375676, iou_loss = 36.759228, total_loss = 38.134903
#  total_bbox = 1700156, rewritten_bbox = 0.984263 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5996: 0.832122, 0.736143 avg loss, 0.000026 rate, 1.158735 seconds, 383744 images, 0.042207 hours left
# Loaded: 0.000045 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.812655, GIOU: 0.803295), Class: 0.984446, Obj: 0.642731, No Obj: 0.002218, .5R: 0.962264, .75R: 0.811321, count: 53, class_loss = 0.298131, iou_loss = 0.596876, total_loss = 0.895008
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.766025, GIOU: 0.755510), Class: 0.972867, Obj: 0.724347, No Obj: 0.002393, .5R: 0.947368, .75R: 0.657895, count: 228, class_loss = 0.987454, iou_loss = 34.370464, total_loss = 35.357918
#  total_bbox = 1700437, rewritten_bbox = 0.984218 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5997: 0.643023, 0.726831 avg loss, 0.000026 rate, 1.136582 seconds, 383808 images, 0.041797 hours left
# Loaded: 0.000038 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.852956, GIOU: 0.849381), Class: 0.999124, Obj: 0.814856, No Obj: 0.001383, .5R: 1.000000, .75R: 0.961538, count: 26, class_loss = 0.086494, iou_loss = 0.319400, total_loss = 0.405894
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.756020, GIOU: 0.743571), Class: 0.964924, Obj: 0.729864, No Obj: 0.002795, .5R: 0.927536, .75R: 0.652174, count: 276, class_loss = 1.421420, iou_loss = 41.733543, total_loss = 43.154964
#  total_bbox = 1700739, rewritten_bbox = 0.984102 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5998: 0.754171, 0.729565 avg loss, 0.000026 rate, 1.147945 seconds, 383872 images, 0.041389 hours left
# Loaded: 0.000052 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.805124, GIOU: 0.800855), Class: 0.976303, Obj: 0.709731, No Obj: 0.001637, .5R: 1.000000, .75R: 0.729730, count: 37, class_loss = 0.176307, iou_loss = 0.386283, total_loss = 0.562590
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.760833, GIOU: 0.752360), Class: 0.969246, Obj: 0.704619, No Obj: 0.002602, .5R: 0.948413, .75R: 0.638889, count: 252, class_loss = 1.282115, iou_loss = 39.545231, total_loss = 40.827347
#  total_bbox = 1701028, rewritten_bbox = 0.983993 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  5999: 0.729448, 0.729554 avg loss, 0.000026 rate, 1.155686 seconds, 383936 images, 0.040981 hours left
# Loaded: 0.000056 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.785285, GIOU: 0.775529), Class: 0.971572, Obj: 0.642231, No Obj: 0.001411, .5R: 0.935484, .75R: 0.741935, count: 31, class_loss = 0.184148, iou_loss = 0.291727, total_loss = 0.475875
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.745259, GIOU: 0.732682), Class: 0.957642, Obj: 0.683701, No Obj: 0.002611, .5R: 0.908046, .75R: 0.620690, count: 261, class_loss = 1.516113, iou_loss = 36.816895, total_loss = 38.333008
#  total_bbox = 1701320, rewritten_bbox = 0.984177 %
#
#  (next mAP calculation at 6264 iterations)
#  Last accuracy mAP@0.5 = 60.01 %, best = 60.04 %
#  6000: 0.850387, 0.741637 avg loss, 0.000026 rate, 0.992161 seconds, 384000 images, 0.040575 hours left
#
#  calculation mAP (mean average precision)...
#  Detection layer: 30 - type = 27
#  Detection layer: 37 - type = 27
# 1768
#  detections_count = 37799, unique_truth_count = 8915
# class_id = 0, name = head, ap = 87.71%   	 (TP = 1894, FP = 367)
# class_id = 1, name = helmet, ap = 91.25%   	 (TP = 5780, FP = 973)
# class_id = 2, name = person, ap = 1.07%   	 (TP = 2, FP = 34)
#
#  for conf_thresh = 0.25, precision = 0.85, recall = 0.86, F1-score = 0.85
#  for conf_thresh = 0.25, TP = 7676, FP = 1374, FN = 1239, average IoU = 67.63 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.600086, or 60.01 %
# Total Detection Time: 73 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.600086
# Saving weights to backup//yolo-obj_6000.weights
# Saving weights to backup//yolo-obj_last.weights
# Saving weights to backup//yolo-obj_final.weights

# %% [markdown]
# # Resultados
# <img src="final_entrenamiento.png" width=360 height=223 align="center"/>
# <img src="chart.png" width=500 height=500 align="center"/>

# %% [markdown]
# ## Probamos el modelo
# 1. Buscar 2 imágenes nuevas.
# 1. Mostrarlas en pantalla (matplotlib).
# 1. Detectar objetos con nuestro modelo.
# 1. Mostrar el resultado de la detección.

# %% [markdown]
# # Prueba del modelo
# Para probar el modelo usamos las librerias de Yolo.
# Existen 2 APIs, la utilizada es la programada en C e incluida a python con el ejemplo provisto en el <a href="https://github.com/AlexeyAB/darknet/#how-to-use-yolo-as-dll-and-so-libraries">Github de darknet de AlexeyAB</a>

# %%
#!python3
"""
Python 3 wrapper for identifying objects in images
Requires DLL compilation
Both the GPU and no-GPU version should be compiled; the no-GPU version should be renamed "yolo_cpp_dll_nogpu.dll".
On a GPU system, you can force CPU evaluation by any of:
- Set global variable DARKNET_FORCE_CPU to True
- Set environment variable CUDA_VISIBLE_DEVICES to -1
- Set environment variable "FORCE_CPU" to "true"
To use, either run performDetect() after import, or modify the end of this file.
See the docstring of performDetect() for parameters.
Directly viewing or returning bounding-boxed images requires scikit-image to be installed (`pip install scikit-image`)
Original *nix 2.7: https://github.com/pjreddie/darknet/blob/0f110834f4e18b30d5f101bf8f1724c34b7b83db/python/darknet.py
Windows Python 2.7 version: https://github.com/AlexeyAB/darknet/blob/fc496d52bf22a0bb257300d3c79be9cd80e722cb/build/darknet/x64/darknet.py
@author: Philip Kahn
@date: 20180503
"""
#pylint: disable=R, W0401, W0614, W0703
from ctypes import *
import math
import random
import os

def sample(probs):
    s = sum(probs)
    probs = [a/s for a in probs]
    r = random.uniform(0, 1)
    for i in range(len(probs)):
        r = r - probs[i]
        if r <= 0:
            return i
    return len(probs)-1

def c_array(ctype, values):
    arr = (ctype*len(values))()
    arr[:] = values
    return arr

class BOX(Structure):
    _fields_ = [("x", c_float),
                ("y", c_float),
                ("w", c_float),
                ("h", c_float)]

class DETECTION(Structure):
    _fields_ = [("bbox", BOX),
                ("classes", c_int),
                ("prob", POINTER(c_float)),
                ("mask", POINTER(c_float)),
                ("objectness", c_float),
                ("sort_class", c_int),
                ("uc", POINTER(c_float)),
                ("points", c_int),
                ("embeddings", POINTER(c_float)),
                ("embedding_size", c_int),
                ("sim", c_float),
                ("track_id", c_int)]

class DETNUMPAIR(Structure):
    _fields_ = [("num", c_int),
                ("dets", POINTER(DETECTION))]

class IMAGE(Structure):
    _fields_ = [("w", c_int),
                ("h", c_int),
                ("c", c_int),
                ("data", POINTER(c_float))]

class METADATA(Structure):
    _fields_ = [("classes", c_int),
                ("names", POINTER(c_char_p))]



#lib = CDLL("/home/pjreddie/documents/darknet/libdarknet.so", RTLD_GLOBAL)
#lib = CDLL("libdarknet.so", RTLD_GLOBAL)
hasGPU = True
if os.name == "nt":
    cwd = os.path.dirname(__file__)
    os.environ['PATH'] = cwd + ';' + os.environ['PATH']
    winGPUdll = os.path.join(cwd, "yolo_cpp_dll.dll")
    winNoGPUdll = os.path.join(cwd, "yolo_cpp_dll_nogpu.dll")
    envKeys = list()
    for k, v in os.environ.items():
        envKeys.append(k)
    try:
        try:
            tmp = os.environ["FORCE_CPU"].lower()
            if tmp in ["1", "true", "yes", "on"]:
                raise ValueError("ForceCPU")
            else:
                print("Flag value '"+tmp+"' not forcing CPU mode")
        except KeyError:
            # We never set the flag
            if 'CUDA_VISIBLE_DEVICES' in envKeys:
                if int(os.environ['CUDA_VISIBLE_DEVICES']) < 0:
                    raise ValueError("ForceCPU")
            try:
                global DARKNET_FORCE_CPU
                if DARKNET_FORCE_CPU:
                    raise ValueError("ForceCPU")
            except NameError:
                pass
            # print(os.environ.keys())
            # print("FORCE_CPU flag undefined, proceeding with GPU")
        if not os.path.exists(winGPUdll):
            raise ValueError("NoDLL")
        lib = CDLL(winGPUdll, RTLD_GLOBAL)
    except (KeyError, ValueError):
        hasGPU = False
        if os.path.exists(winNoGPUdll):
            lib = CDLL(winNoGPUdll, RTLD_GLOBAL)
            print("Notice: CPU-only mode")
        else:
            # Try the other way, in case no_gpu was
            # compile but not renamed
            lib = CDLL(winGPUdll, RTLD_GLOBAL)
            print("Environment variables indicated a CPU run, but we didn't find `"+winNoGPUdll+"`. Trying a GPU run anyway.")
else:
    lib = CDLL("./libdarknet.so", RTLD_GLOBAL)
lib.network_width.argtypes = [c_void_p]
lib.network_width.restype = c_int
lib.network_height.argtypes = [c_void_p]
lib.network_height.restype = c_int

copy_image_from_bytes = lib.copy_image_from_bytes
copy_image_from_bytes.argtypes = [IMAGE,c_char_p]

def network_width(net):
    return lib.network_width(net)

def network_height(net):
    return lib.network_height(net)

predict = lib.network_predict_ptr
predict.argtypes = [c_void_p, POINTER(c_float)]
predict.restype = POINTER(c_float)

if hasGPU:
    set_gpu = lib.cuda_set_device
    set_gpu.argtypes = [c_int]

init_cpu = lib.init_cpu

make_image = lib.make_image
make_image.argtypes = [c_int, c_int, c_int]
make_image.restype = IMAGE

get_network_boxes = lib.get_network_boxes
get_network_boxes.argtypes = [c_void_p, c_int, c_int, c_float, c_float, POINTER(c_int), c_int, POINTER(c_int), c_int]
get_network_boxes.restype = POINTER(DETECTION)

make_network_boxes = lib.make_network_boxes
make_network_boxes.argtypes = [c_void_p]
make_network_boxes.restype = POINTER(DETECTION)

free_detections = lib.free_detections
free_detections.argtypes = [POINTER(DETECTION), c_int]

free_batch_detections = lib.free_batch_detections
free_batch_detections.argtypes = [POINTER(DETNUMPAIR), c_int]

free_ptrs = lib.free_ptrs
free_ptrs.argtypes = [POINTER(c_void_p), c_int]

network_predict = lib.network_predict_ptr
network_predict.argtypes = [c_void_p, POINTER(c_float)]

reset_rnn = lib.reset_rnn
reset_rnn.argtypes = [c_void_p]

load_net = lib.load_network
load_net.argtypes = [c_char_p, c_char_p, c_int]
load_net.restype = c_void_p

load_net_custom = lib.load_network_custom
load_net_custom.argtypes = [c_char_p, c_char_p, c_int, c_int]
load_net_custom.restype = c_void_p

do_nms_obj = lib.do_nms_obj
do_nms_obj.argtypes = [POINTER(DETECTION), c_int, c_int, c_float]

do_nms_sort = lib.do_nms_sort
do_nms_sort.argtypes = [POINTER(DETECTION), c_int, c_int, c_float]

free_image = lib.free_image
free_image.argtypes = [IMAGE]

letterbox_image = lib.letterbox_image
letterbox_image.argtypes = [IMAGE, c_int, c_int]
letterbox_image.restype = IMAGE

load_meta = lib.get_metadata
lib.get_metadata.argtypes = [c_char_p]
lib.get_metadata.restype = METADATA

load_image = lib.load_image_color
load_image.argtypes = [c_char_p, c_int, c_int]
load_image.restype = IMAGE

rgbgr_image = lib.rgbgr_image
rgbgr_image.argtypes = [IMAGE]

predict_image = lib.network_predict_image
predict_image.argtypes = [c_void_p, IMAGE]
predict_image.restype = POINTER(c_float)

predict_image_letterbox = lib.network_predict_image_letterbox
predict_image_letterbox.argtypes = [c_void_p, IMAGE]
predict_image_letterbox.restype = POINTER(c_float)

network_predict_batch = lib.network_predict_batch
network_predict_batch.argtypes = [c_void_p, IMAGE, c_int, c_int, c_int,
                                   c_float, c_float, POINTER(c_int), c_int, c_int]
network_predict_batch.restype = POINTER(DETNUMPAIR)

def array_to_image(arr):
    import numpy as np
    # need to return old values to avoid python freeing memory
    arr = arr.transpose(2,0,1)
    c = arr.shape[0]
    h = arr.shape[1]
    w = arr.shape[2]
    arr = np.ascontiguousarray(arr.flat, dtype=np.float32) / 255.0
    data = arr.ctypes.data_as(POINTER(c_float))
    im = IMAGE(w,h,c,data)
    return im, arr

def classify(net, meta, im):
    out = predict_image(net, im)
    res = []
    for i in range(meta.classes):
        if altNames is None:
            nameTag = meta.names[i]
        else:
            nameTag = altNames[i]
        res.append((nameTag, out[i]))
    res = sorted(res, key=lambda x: -x[1])
    return res

def detect(net, meta, image, thresh=.5, hier_thresh=.5, nms=.45, debug= False):
    """
    Performs the meat of the detection
    """
    #pylint: disable= C0321
    im = load_image(image, 0, 0)
    if debug: print("Loaded image")
    ret = detect_image(net, meta, im, thresh, hier_thresh, nms, debug)
    free_image(im)
    if debug: print("freed image")
    return ret

def detect_image(net, meta, im, thresh=.5, hier_thresh=.5, nms=.45, debug= False):
    #import cv2
    #custom_image_bgr = cv2.imread(image) # use: detect(,,imagePath,)
    #custom_image = cv2.cvtColor(custom_image_bgr, cv2.COLOR_BGR2RGB)
    #custom_image = cv2.resize(custom_image,(lib.network_width(net), lib.network_height(net)), interpolation = cv2.INTER_LINEAR)
    #import scipy.misc
    #custom_image = scipy.misc.imread(image)
    #im, arr = array_to_image(custom_image)		# you should comment line below: free_image(im)
    num = c_int(0)
    if debug: print("Assigned num")
    pnum = pointer(num)
    if debug: print("Assigned pnum")
    predict_image(net, im)
    letter_box = 0
    #predict_image_letterbox(net, im)
    #letter_box = 1
    if debug: print("did prediction")
    #dets = get_network_boxes(net, custom_image_bgr.shape[1], custom_image_bgr.shape[0], thresh, hier_thresh, None, 0, pnum, letter_box) # OpenCV
    dets = get_network_boxes(net, im.w, im.h, thresh, hier_thresh, None, 0, pnum, letter_box)
    if debug: print("Got dets")
    num = pnum[0]
    if debug: print("got zeroth index of pnum")
    if nms:
        do_nms_sort(dets, num, meta.classes, nms)
    if debug: print("did sort")
    res = []
    if debug: print("about to range")
    for j in range(num):
        if debug: print("Ranging on "+str(j)+" of "+str(num))
        if debug: print("Classes: "+str(meta), meta.classes, meta.names)
        for i in range(meta.classes):
            if debug: print("Class-ranging on "+str(i)+" of "+str(meta.classes)+"= "+str(dets[j].prob[i]))
            if dets[j].prob[i] > 0:
                b = dets[j].bbox
                if altNames is None:
                    nameTag = meta.names[i]
                else:
                    nameTag = altNames[i]
                if debug:
                    print("Got bbox", b)
                    print(nameTag)
                    print(dets[j].prob[i])
                    print((b.x, b.y, b.w, b.h))
                res.append((nameTag, dets[j].prob[i], (b.x, b.y, b.w, b.h)))
    if debug: print("did range")
    res = sorted(res, key=lambda x: -x[1])
    if debug: print("did sort")
    free_detections(dets, num)
    if debug: print("freed detections")
    return res


netMain = None
metaMain = None
altNames = None

def performDetect(imagePath="data/dog.jpg", thresh= 0.25, configPath = "./cfg/yolov4.cfg", weightPath = "yolov4.weights", metaPath= "./cfg/coco.data", showImage= True, makeImageOnly = False, initOnly= False):
    """
    Convenience function to handle the detection and returns of objects.
    Displaying bounding boxes requires libraries scikit-image and numpy
    Parameters
    ----------------
    imagePath: str
        Path to the image to evaluate. Raises ValueError if not found
    thresh: float (default= 0.25)
        The detection threshold
    configPath: str
        Path to the configuration file. Raises ValueError if not found
    weightPath: str
        Path to the weights file. Raises ValueError if not found
    metaPath: str
        Path to the data file. Raises ValueError if not found
    showImage: bool (default= True)
        Compute (and show) bounding boxes. Changes return.
    makeImageOnly: bool (default= False)
        If showImage is True, this won't actually *show* the image, but will create the array and return it.
    initOnly: bool (default= False)
        Only initialize globals. Don't actually run a prediction.
    Returns
    ----------------------
    When showImage is False, list of tuples like
        ('obj_label', confidence, (bounding_box_x_px, bounding_box_y_px, bounding_box_width_px, bounding_box_height_px))
        The X and Y coordinates are from the center of the bounding box. Subtract half the width or height to get the lower corner.
    Otherwise, a dict with
        {
            "detections": as above
            "image": a numpy array representing an image, compatible with scikit-image
            "caption": an image caption
        }
    """
    # Import the global variables. This lets us instance Darknet once, then just call performDetect() again without instancing again
    global metaMain, netMain, altNames #pylint: disable=W0603
    assert 0 < thresh < 1, "Threshold should be a float between zero and one (non-inclusive)"
    if not os.path.exists(configPath):
        raise ValueError("Invalid config path `"+os.path.abspath(configPath)+"`")
    if not os.path.exists(weightPath):
        raise ValueError("Invalid weight path `"+os.path.abspath(weightPath)+"`")
    if not os.path.exists(metaPath):
        raise ValueError("Invalid data file path `"+os.path.abspath(metaPath)+"`")
    if netMain is None:
        netMain = load_net_custom(configPath.encode("ascii"), weightPath.encode("ascii"), 0, 1)  # batch size = 1
    if metaMain is None:
        metaMain = load_meta(metaPath.encode("ascii"))
    if altNames is None:
        # In Python 3, the metafile default access craps out on Windows (but not Linux)
        # Read the names file and create a list to feed to detect
        try:
            with open(metaPath) as metaFH:
                metaContents = metaFH.read()
                import re
                match = re.search("names *= *(.*)$", metaContents, re.IGNORECASE | re.MULTILINE)
                if match:
                    result = match.group(1)
                else:
                    result = None
                try:
                    if os.path.exists(result):
                        with open(result) as namesFH:
                            namesList = namesFH.read().strip().split("\n")
                            altNames = [x.strip() for x in namesList]
                except TypeError:
                    pass
        except Exception:
            pass
    if initOnly:
        print("Initialized detector")
        return None
    if not os.path.exists(imagePath):
        raise ValueError("Invalid image path `"+os.path.abspath(imagePath)+"`")
    # Do the detection
    #detections = detect(netMain, metaMain, imagePath, thresh)	# if is used cv2.imread(image)
    detections = detect(netMain, metaMain, imagePath.encode("ascii"), thresh)
    if showImage:
        try:
            from skimage import io, draw
            import numpy as np
            image = io.imread(imagePath)
            print("*** "+str(len(detections))+" Results, color coded by confidence ***")
            imcaption = []
            for detection in detections:
                label = detection[0]
                confidence = detection[1]
                pstring = label+": "+str(np.rint(100 * confidence))+"%"
                imcaption.append(pstring)
                print(pstring)
                bounds = detection[2]
                shape = image.shape
                # x = shape[1]
                # xExtent = int(x * bounds[2] / 100)
                # y = shape[0]
                # yExtent = int(y * bounds[3] / 100)
                yExtent = int(bounds[3])
                xEntent = int(bounds[2])
                # Coordinates are around the center
                xCoord = int(bounds[0] - bounds[2]/2)
                yCoord = int(bounds[1] - bounds[3]/2)
                boundingBox = [
                    [xCoord, yCoord],
                    [xCoord, yCoord + yExtent],
                    [xCoord + xEntent, yCoord + yExtent],
                    [xCoord + xEntent, yCoord]
                ]
                # Wiggle it around to make a 3px border
                rr, cc = draw.polygon_perimeter([x[1] for x in boundingBox], [x[0] for x in boundingBox], shape= shape)
                rr2, cc2 = draw.polygon_perimeter([x[1] + 1 for x in boundingBox], [x[0] for x in boundingBox], shape= shape)
                rr3, cc3 = draw.polygon_perimeter([x[1] - 1 for x in boundingBox], [x[0] for x in boundingBox], shape= shape)
                rr4, cc4 = draw.polygon_perimeter([x[1] for x in boundingBox], [x[0] + 1 for x in boundingBox], shape= shape)
                rr5, cc5 = draw.polygon_perimeter([x[1] for x in boundingBox], [x[0] - 1 for x in boundingBox], shape= shape)
                boxColor = (int(255 * (1 - (confidence ** 2))), int(255 * (confidence ** 2)), 0)
                draw.set_color(image, (rr, cc), boxColor, alpha= 0.8)
                draw.set_color(image, (rr2, cc2), boxColor, alpha= 0.8)
                draw.set_color(image, (rr3, cc3), boxColor, alpha= 0.8)
                draw.set_color(image, (rr4, cc4), boxColor, alpha= 0.8)
                draw.set_color(image, (rr5, cc5), boxColor, alpha= 0.8)
            if not makeImageOnly:
                io.imshow(image)
                io.show()
            detections = {
                "detections": detections,
                "image": image,
                "caption": "\n<br/>".join(imcaption)
            }
        except Exception as e:
            print("Unable to show image: "+str(e))
    return detections

def performBatchDetect(thresh= 0.25, configPath = "./cfg/yolov4.cfg", weightPath = "yolov4.weights", metaPath= "./cfg/coco.data", hier_thresh=.5, nms=.45, batch_size=3):
    import cv2
    import numpy as np
    # NB! Image sizes should be the same
    # You can change the images, yet, be sure that they have the same width and height
    img_samples = ['data/person.jpg', 'data/person.jpg', 'data/person.jpg']
    image_list = [cv2.imread(k) for k in img_samples]

    net = load_net_custom(configPath.encode('utf-8'), weightPath.encode('utf-8'), 0, batch_size)
    meta = load_meta(metaPath.encode('utf-8'))
    pred_height, pred_width, c = image_list[0].shape
    net_width, net_height = (network_width(net), network_height(net))
    img_list = []
    for custom_image_bgr in image_list:
        custom_image = cv2.cvtColor(custom_image_bgr, cv2.COLOR_BGR2RGB)
        custom_image = cv2.resize(
            custom_image, (net_width, net_height), interpolation=cv2.INTER_NEAREST)
        custom_image = custom_image.transpose(2, 0, 1)
        img_list.append(custom_image)

    arr = np.concatenate(img_list, axis=0)
    arr = np.ascontiguousarray(arr.flat, dtype=np.float32) / 255.0
    data = arr.ctypes.data_as(POINTER(c_float))
    im = IMAGE(net_width, net_height, c, data)

    batch_dets = network_predict_batch(net, im, batch_size, pred_width,
                                                pred_height, thresh, hier_thresh, None, 0, 0)
    batch_boxes = []
    batch_scores = []
    batch_classes = []
    for b in range(batch_size):
        num = batch_dets[b].num
        dets = batch_dets[b].dets
        if nms:
            do_nms_obj(dets, num, meta.classes, nms)
        boxes = []
        scores = []
        classes = []
        for i in range(num):
            det = dets[i]
            score = -1
            label = None
            for c in range(det.classes):
                p = det.prob[c]
                if p > score:
                    score = p
                    label = c
            if score > thresh:
                box = det.bbox
                left, top, right, bottom = map(int,(box.x - box.w / 2, box.y - box.h / 2,
                                            box.x + box.w / 2, box.y + box.h / 2))
                boxes.append((top, left, bottom, right))
                scores.append(score)
                classes.append(label)
                boxColor = (int(255 * (1 - (score ** 2))), int(255 * (score ** 2)), 0)
                cv2.rectangle(image_list[b], (left, top),
                          (right, bottom), boxColor, 2)
        cv2.imwrite(os.path.basename(img_samples[b]),image_list[b])

        batch_boxes.append(boxes)
        batch_scores.append(scores)
        batch_classes.append(classes)
    free_batch_detections(batch_dets, batch_size)
    return batch_boxes, batch_scores, batch_classes

# %%
if __name__ == "__main__":
    performDetect("/content/darknet/data/obra.jpg", 0.25, "/content/darknet/cfg/yolo-obj.cfg", "/content/darknet/backup/yolo-obj_final.weights", "/content/darknet/data/obj.data", True, False, False)
    performDetect("/content/darknet/data/dog.jpg", 0.25, "/content/darknet/cfg/yolo-obj.cfg", "/content/darknet/backup/yolo-obj_final.weights", "/content/darknet/data/obj.data", True, False, False)
    #Uncomment the following line to see batch inference working 
    #print(performBatchDetect())
# Out:
# *** 1 Results, color coded by confidence ***
# helmet: 100.0%
# *** 0 Results, color coded by confidence ***
